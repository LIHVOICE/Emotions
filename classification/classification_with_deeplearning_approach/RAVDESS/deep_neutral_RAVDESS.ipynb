# %%
from __future__ import print_function

#Numpy, pandas ans os
import numpy as np
import pandas as pd
import os
# matplotlib for displaying the output
import matplotlib.pyplot as plt

# Librosa for audio
import librosa


#parselmouth for audio
import parselmouth
from parselmouth.praat import call
from sklearn.decomposition import PCA
import statistics

#essentia

import essentia.standard
import essentia.streaming
from essentia.standard import *


#librairies for classification
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split, cross_val_predict, KFold, cross_val_score
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import classification_report, make_scorer, confusion_matrix

from sklearn.metrics import roc_auc_score
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline

from imblearn.over_sampling import ADASYN
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest

from sklearn.model_selection import GridSearchCV
import joblib

#Deep learning

### Plot imports ###

import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras.models import load_model
import seaborn as sns 
from keras.utils import np_utils
from keras.utils import plot_model
from sklearn.preprocessing import LabelEncoder

#for warning
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category= ConvergenceWarning)

warnings.filterwarnings("ignore", category= UserWarning)
warnings.filterwarnings("ignore", category= RuntimeWarning)

# %% [markdown]
# Dataframe to match audio with emotion

# %%
parent_dir = "ravdess" #audio data folder
def prepare_datadf(parent_dir): # a function whose parameter is the audio folder
    df = pd.DataFrame(columns = ['audio', 'label']) #dataframe columns
    
    for  fichier_audio in os.listdir(parent_dir): # for each element in the audio folder
        folder_path = os.path.join(parent_dir, fichier_audio) # path of each item  in the audio folder
        
       
        
        if(os.path.isdir(folder_path)): 
            audios = os.listdir(folder_path) #content of each emotional file
            for i in audios:
                emotion = None
                if i.endswith('outNoise.wav'):
                    if i[7] == '1':   ##this specifies that we class neutral emotion against the others
                                    #1 represents the 7th column of the file name
                                    # This number varies for each emotion(ex calm = '2', fearfull = '6')
                        emotion = 1
                    
                    else:
                        emotion = 0
                    df = df.append(pd.DataFrame({'audio':[os.path.join(fichier_audio, i)], 'label':[emotion]}), 
                           ignore_index=True) #adding values to the defined df:
                                            #the audio column will take the audios_path, 
                                            #and the emotion column will take the corresponding emotion, ie the name of the folder
    #Shuffling for randomness
    df = df.sample(frac=1.0).reset_index(drop=True)
    return df
datadf = prepare_datadf(parent_dir) #function call
display(datadf.head()) #dataframe display
# Out:
#                                              audio label
# 0  fearfull/03-01-06-01-01-01-15_norm_outNoise.wav     0
# 1   disgust/03-01-07-01-01-02-05_norm_outNoise.wav     0
# 2  fearfull/03-01-06-01-01-02-10_norm_outNoise.wav     0
# 3   neutral/03-01-01-01-01-01-14_norm_outNoise.wav     1
# 4       sad/03-01-04-01-02-02-21_norm_outNoise.wav     0

# %% [markdown]
# Number of labels 1 and 0

# %%
array=datadf.values
audios=array[:,0]
emotions=array[:,1]
print(datadf.label.value_counts())
# Out:
# 0    1149
# 1      96
# Name: label, dtype: int64

# %% [markdown]
# Preprocessing

# %% [markdown]
# Function for framing and windowing the audio_files

# %%
def fram_window(audio_path):
    loader = essentia.standard.MonoLoader(filename= audio_path)

    # and then we actually perform the loading:
    audio = loader()

    w = Windowing(type = 'hann')
    spectrum = Spectrum() 
    #default parameter (hopsize and framesize)
    hopSize = 512
    frameSize = 1024 
    for frame in FrameGenerator(audio, frameSize=1024, hopSize=512, startFromZero=True):
        spect = spectrum(w(frame))
    return spect

# %% [markdown]
# function for features extraction:

# %%
def extract_features(audio_path):
    features = []
    
    
    #Load audios with the different libraries
      
    y,sr = librosa.load(audio_path)
    sound = parselmouth.Sound(audio_path)
    fs, sig = scipy.io.wavfile.read(audio_path) 
    
    pitch = call(sound, "To Pitch", 0.0, 75, 600)
    mean_pitch = call(pitch, "Get mean", 0, 0, "Hertz")
    
    spec =  fram_window(audio_path) 
    duration = librosa.get_duration(y= spec, sr=sr)
    energy = np.sum(spec ** 2) / np.float64(len(spec))
            
    lpc = librosa.core.lpc(spec,16)
            
    zcr = librosa.feature.zero_crossing_rate(spec)
               
    #gfccs = gfcc(sig= spec, fs=fs, num_ceps=13)    
    mfcc = librosa.feature.mfcc(y= spec, sr=sr, n_mfcc = 13)
        
    harmonicity = call(sound, "To Harmonicity (cc)", 0.01, 75, 0.1, 1.0)
    HNR = call(harmonicity, "Get mean", 0, 0)
                
    pointProcess = call(sound, "To PointProcess (periodic, cc)", 75, 500)
    localJitter = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
    localabsoluteJitter = call(pointProcess, "Get jitter (local, absolute)", 0, 0, 0.0001, 0.02, 1.3)

    localShimmer =  call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    localdbShimmer = call([sound, pointProcess], "Get shimmer (local_dB)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
        
    formants = call(sound, "To Formant (burg)", 0.0, 5, 5500, 0.025, 100)
    numPoints = call(pointProcess, "Get number of points")

    f1_list = []
    f2_list = []
    f3_list = []
    f4_list = []
    
    # Measure formants only at glottal pulses
    for point in range(0, numPoints):
        point += 1
        t = call(pointProcess, "Get time from index", point)
        f1 = call(formants, "Get value at time", 1, t, 'Hertz', 'Linear')
        f2 = call(formants, "Get value at time", 2, t, 'Hertz', 'Linear')
        f3 = call(formants, "Get value at time", 3, t, 'Hertz', 'Linear')
        f4 = call(formants, "Get value at time", 4, t, 'Hertz', 'Linear')
        f1_list.append(f1)
        f2_list.append(f2)
        f3_list.append(f3)
        f4_list.append(f4)
        
    f1_list = [f1 for f1 in f1_list if str(f1) != 'nan']
    f2_list = [f2 for f2 in f2_list if str(f2) != 'nan']
    f3_list = [f3 for f3 in f3_list if str(f3) != 'nan']
    
    f4_list = [f4 for f4 in f4_list if str(f4) != 'nan']

    f1_mean = statistics.mean(f1_list)
    f2_mean = statistics.mean(f2_list)
    f3_mean = statistics.mean(f3_list)
    f4_mean = statistics.mean(f4_list)
    
    rapJitter = call(pointProcess, "Get jitter (rap)", 0, 0, 0.0001, 0.02, 1.3)
    ppq5Jitter = call(pointProcess, "Get jitter (ppq5)", 0, 0, 0.0001, 0.02, 1.3)
    ddpJitter = call(pointProcess, "Get jitter (ddp)", 0, 0, 0.0001, 0.02, 1.3)   
            
    apq3Shimmer = call([sound, pointProcess], "Get shimmer (apq3)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    aqpq5Shimmer = call([sound, pointProcess], "Get shimmer (apq5)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq11Shimmer =  call([sound, pointProcess], "Get shimmer (apq11)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    ddaShimmer = call([sound, pointProcess], "Get shimmer (dda)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    
    features.append(mean_pitch)
    features.append(duration)
    features.append(energy)
    features.append(np.mean(zcr))
    features.append(np.mean(lpc))
    
        
    features.append(np.mean(mfcc))
    
    #features.append(np.mean(gfccs))
    features.append(HNR)
    
    features.append(localJitter)
    features.append(np.mean(localabsoluteJitter))
    
    features.append(localShimmer)
    features.append(localdbShimmer)
    features.append(f1_mean)   
    features.append(f2_mean)
    features.append(f3_mean)
    features.append(f4_mean)
        
    features.append(rapJitter)
    features.append(ppq5Jitter)
    features.append(ddpJitter)
    
    features.append(apq3Shimmer)
    features.append(aqpq5Shimmer)
    features.append(apq11Shimmer)
    features.append(ddaShimmer)
        
    return features

# %% [markdown]
# Application of features extraction function on all audios

# %%
all_features = []
for audio_file in array[:,0]:
    if audio_file.endswith('.wav'):
        
        features = extract_features(parent_dir+'/'+audio_file)
        all_features.append(features)

# %%
print(len(all_features))
# Out:
# 1245

# %% [markdown]
# Encode labels

# %%
encod = preprocessing.LabelEncoder()
emotions = array[:,1]
encod.fit(emotions)
list(encod.classes_)
labels=encod.transform(emotions)

# %% [markdown]
# Scale features

# %%
scaler = StandardScaler()
scaler.fit(all_features)
X_scaler = scaler.transform(all_features)

# %% [markdown]
# Oversampling

# %%
ada = ADASYN(sampling_strategy = 0.6)
X, y = ada.fit_sample(X_scaler, labels.ravel())
print("After OverSampling, counts of label '1': {}".format(sum(y==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y==0)))
# Out:
# After OverSampling, counts of label '1': 676
# After OverSampling, counts of label '0': 1149

# %% [markdown]
# Process to select features after oversampling with ADASYN : the code first takes in a list the position of the features that are deleted, during the 1000 iterations, then uses a dataframe to count them. we notice that the features " [1, 2, 3, 4, 8, 13] " are deleted 670 times.

# %%
compt=0
df = pd.DataFrame(columns = ['iteration', 'X_removed'])
while compt < 1000:
    ada = ADASYN(sampling_strategy = 0.6)
    
    X, y = ada.fit_sample(X_scaler, labels.ravel())
    X = np.asarray(X)
    Kbest = SelectKBest(k="all")
    selec_features = Kbest.fit(X, y)
    alpha = 0.01
    #remove non_signifiant features selection
    X_selec = X[:,np.where(selec_features.pvalues_ < alpha)[0]]
    
    pos_removed = []    
    for i in range(len(X[0])):
   
        if X[0][i] not in X_selec[0]:
            #print(i)
            pos_removed.append(i)
            str_pos_removed = str(pos_removed)
    #print(pos_removed)
    
    compt = compt + 1
    df= df.append(pd.DataFrame({'iteration':[compt], 'X_removed':[str_pos_removed]}), ignore_index=True)
display(df.head())

print("Number of occurrences of features that are removed :")
df["X_removed"].value_counts()
# Out:
#   iteration            X_removed
# 0         1      [1, 2, 3, 4, 8]
# 1         2  [1, 2, 3, 4, 8, 13]
# 2         3      [1, 2, 3, 4, 8]
# 3         4      [1, 2, 3, 4, 8]
# 4         5  [1, 2, 3, 4, 8, 13]
# Number of occurrences of features that are removed :
# [1, 2, 3, 4, 8, 13]    670
# [1, 2, 3, 4, 8]        325
# [1, 2, 3, 8, 13]         5
# Name: X_removed, dtype: int64

# %%
#manually feature selection
X_selected = []
for i in range(len(X)):
    #print(w[i][0])
    X_selected.append([X[i][0],  X[i][5], X[i][6], X[i][7],  X[i][9], X[i][10],
               X[i][11], X[i][12], X[i][14],  X[i][15], 
                X[i][16], X[i][17], X[i][18], X[i][19],  X[i][20], X[i][21]])

# %% [markdown]
# Split dataset to Train, Test and Val

# %%
#split train test
X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=1)

print(len(X_train))
print(len(X_test))
print(len(X_val))
# Out:
# 1168
# 365
# 292

# %% [markdown]
# Reshape Labels and features for deep learning model

# %% [markdown]
# Features

# %%
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
X_val = np.asarray(X_val)

# %%
 X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
 X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))

 print(X_train.shape)
 print(X_test.shape)
 print(X_val.shape)
# Out:
# (1168, 16, 1)
# (365, 16, 1)
# (292, 16, 1)

# %% [markdown]
# labels

# %%
from keras.utils import to_categorical

# Encode the classification labels
le = LabelEncoder()
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_val = to_categorical(y_val)

print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (1168, 2)
# (365, 2)
# (292, 2)

# %% [markdown]
# ### Classification

# %% [markdown]
# Model

# %%
input_y = Input(shape= (16,1))

# %%
#CNN
y = Conv1D(256, kernel_size=5, strides= 1,  name='Conv_1', padding = 'same')(input_y)
y = BatchNormalization( name='BatchNorm_1')(y)
y = Activation('elu', name='Activ_1')(y)

y = Conv1D(128, kernel_size=5, strides= 1,  name='Conv_2', padding = 'same')(input_y)
y = Activation('elu', name='Activ_2')(y)

y = Dropout(0.2, name='Drop_1')(y)
y = BatchNormalization( name='BatchNorm_2')(y)
y = MaxPooling1D(pool_size=8, name = 'maxpooling', padding = 'same') (y) 

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_3', padding = 'same')(y)
y = Activation('elu', name='Activ_3')(y)

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_4', padding = 'same')(y)
y = Activation('elu', name='Activ_4')(y)

y = Conv1D(128, kernel_size=5, strides= 1,  name='Conv_5', padding = 'same')(input_y)
y = BatchNormalization( name='BatchNorm_3')(y)
y = Activation('elu', name='Activ_5')(y)

y = Dropout(0.2, name='Drop_2')(y)     

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_6', padding = 'same')(y)

y = Flatten(name='Flat')(y)
y = Dropout(0.2, name='Drop_3')(y)  

y = Dense(y_train.shape[1],  name='dense')(y)

y = BatchNormalization(name='BatchNorm_4')(y)

y = Activation('softmax', name='Activ_6')(y)









# Build final model
model = Model(inputs=input_y, outputs=y)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 16, 1)]           0
# _________________________________________________________________
# Conv_5 (Conv1D)              (None, 16, 128)           768
# _________________________________________________________________
# BatchNorm_3 (BatchNormalizat (None, 16, 128)           512
# _________________________________________________________________
# Activ_5 (Activation)         (None, 16, 128)           0
# _________________________________________________________________
# Drop_2 (Dropout)             (None, 16, 128)           0
# _________________________________________________________________
# Conv_6 (Conv1D)              (None, 16, 128)           82048
# _________________________________________________________________
# Flat (Flatten)               (None, 2048)              0
# _________________________________________________________________
# Drop_3 (Dropout)             (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 4098
# _________________________________________________________________
# BatchNorm_4 (BatchNormalizat (None, 2)                 8
# _________________________________________________________________
# Activ_6 (Activation)         (None, 2)                 0
# =================================================================
# Total params: 87,434
# Trainable params: 87,174
# Non-trainable params: 260
# _________________________________________________________________

# %%
METRICS = [
      
      keras.metrics.BinaryAccuracy(name='accuracy'),
      
      keras.metrics.AUC(name='auc'),
]

# %%
# Compile model
model.compile(optimizer=RMSprop(lr=0.00001, decay=1e-6), loss='categorical_crossentropy', metrics=[METRICS])

# Save best model
best_model_save = ModelCheckpoint('neutral_ravdess.hdf5', save_best_only=True, monitor='val_loss', mode='auto')

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience = 30,  verbose=1, mode='auto')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=700, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/700
# 19/19 [==============================] - 1s 53ms/step - loss: 0.7489 - accuracy: 0.5642 - auc: 0.5891 - val_loss: 0.6803 - val_accuracy: 0.5260 - val_auc: 0.5875
# Epoch 2/700
# 19/19 [==============================] - 1s 32ms/step - loss: 0.6578 - accuracy: 0.6259 - auc: 0.6877 - val_loss: 0.6791 - val_accuracy: 0.5260 - val_auc: 0.5912
# Epoch 3/700
# 19/19 [==============================] - 1s 31ms/step - loss: 0.6461 - accuracy: 0.6455 - auc: 0.6960 - val_loss: 0.6750 - val_accuracy: 0.5205 - val_auc: 0.6036
# Epoch 4/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.6104 - accuracy: 0.6712 - auc: 0.7342 - val_loss: 0.6709 - val_accuracy: 0.5342 - val_auc: 0.6167
# Epoch 5/700
# 19/19 [==============================] - 1s 33ms/step - loss: 0.5882 - accuracy: 0.6875 - auc: 0.7530 - val_loss: 0.6643 - val_accuracy: 0.5534 - val_auc: 0.6331
# Epoch 6/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5759 - accuracy: 0.6961 - auc: 0.7684 - val_loss: 0.6587 - val_accuracy: 0.5699 - val_auc: 0.6489
# Epoch 7/700
# 19/19 [==============================] - 1s 31ms/step - loss: 0.5671 - accuracy: 0.7038 - auc: 0.7744 - val_loss: 0.6521 - val_accuracy: 0.5808 - val_auc: 0.6654
# Epoch 8/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5620 - accuracy: 0.7089 - auc: 0.7785 - val_loss: 0.6442 - val_accuracy: 0.5945 - val_auc: 0.6828
# Epoch 9/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5650 - accuracy: 0.7046 - auc: 0.7768 - val_loss: 0.6356 - val_accuracy: 0.6192 - val_auc: 0.6999
# Epoch 10/700
# 19/19 [==============================] - 1s 32ms/step - loss: 0.5611 - accuracy: 0.7226 - auc: 0.7842 - val_loss: 0.6287 - val_accuracy: 0.6411 - val_auc: 0.7113
# Epoch 11/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5486 - accuracy: 0.7243 - auc: 0.7948 - val_loss: 0.6218 - val_accuracy: 0.6438 - val_auc: 0.7240
# Epoch 12/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.5501 - accuracy: 0.7235 - auc: 0.7906 - val_loss: 0.6146 - val_accuracy: 0.6575 - val_auc: 0.7332
# Epoch 13/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5516 - accuracy: 0.7243 - auc: 0.7915 - val_loss: 0.6055 - val_accuracy: 0.6712 - val_auc: 0.7463
# Epoch 14/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5427 - accuracy: 0.7303 - auc: 0.7995 - val_loss: 0.5975 - val_accuracy: 0.6822 - val_auc: 0.7569
# Epoch 15/700
# 19/19 [==============================] - 1s 32ms/step - loss: 0.5246 - accuracy: 0.7474 - auc: 0.8147 - val_loss: 0.5908 - val_accuracy: 0.6877 - val_auc: 0.7661
# Epoch 16/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.5378 - accuracy: 0.7320 - auc: 0.8019 - val_loss: 0.5817 - val_accuracy: 0.7041 - val_auc: 0.7763
# Epoch 17/700
# 19/19 [==============================] - 1s 32ms/step - loss: 0.
700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.4440 - accuracy: 0.7962 - auc: 0.8764 - val_loss: 0.4365 - val_accuracy: 0.8027 - val_auc: 0.8828
# Epoch 272/700
# 19/19 [==============================] - 0s 26ms/step - loss: 0.4511 - accuracy: 0.7928 - auc: 0.8706 - val_loss: 0.4360 - val_accuracy: 0.8055 - val_auc: 0.8825
# Epoch 273/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4473 - accuracy: 0.7928 - auc: 0.8724 - val_loss: 0.4341 - val_accuracy: 0.8055 - val_auc: 0.8843
# Epoch 274/700
# ...
# Epoch 611/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4151 - accuracy: 0.8193 - auc: 0.8932 - val_loss: 0.3978 - val_accuracy: 0.8356 - val_auc: 0.9068
# Epoch 612/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4174 - accuracy: 0.8211 - auc: 0.8932 - val_loss: 0.3979 - val_accuracy: 0.8384 - val_auc: 0.9068
# Epoch 613/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4138 - accuracy: 0.8176 - auc: 0.8942 - val_loss: 0.3982 - val_accuracy: 0.8411 - val_auc: 0.9072
# Epoch 614/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4049 - accuracy: 0.8236 - auc: 0.9010 - val_loss: 0.3978 - val_accuracy: 0.8411 - val_auc: 0.9071
# Epoch 615/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4126 - accuracy: 0.8288 - auc: 0.8954 - val_loss: 0.3983 - val_accuracy: 0.8466 - val_auc: 0.9069
# Epoch 616/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4023 - accuracy: 0.8339 - auc: 0.9023 - val_loss: 0.3982 - val_accuracy: 0.8438 - val_auc: 0.9070
# Epoch 617/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4136 - accuracy: 0.8219 - auc: 0.8951 - val_loss: 0.3982 - val_accuracy: 0.8466 - val_auc: 0.9080
# Epoch 618/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4233 - accuracy: 0.8168 - auc: 0.8880 - val_loss: 0.3981 - val_accuracy: 0.8438 - val_auc: 0.9075
# Epoch 619/700
# 19/19 [==============================] - 1s 33ms/step - loss: 0.4142 - accuracy: 0.8151 - auc: 0.8946 - val_loss: 0.3966 - val_accuracy: 0.8493 - val_auc: 0.9088
# Epoch 620/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4029 - accuracy: 0.8228 - auc: 0.9020 - val_loss: 0.3971 - val_accuracy: 0.8466 - val_auc: 0.9085
# Epoch 621/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4042 - accuracy: 0.8296 - auc: 0.9014 - val_loss: 0.3976 - val_accuracy: 0.8466 - val_auc: 0.9082
# Epoch 622/700
# 19/19 [==============================] - 1s 27ms/step - loss: 0.4099 - accuracy: 0.8219 - auc: 0.8985 - val_loss: 0.3990 - val_accuracy: 0.8466 - val_auc: 0.9082
# Epoch 623/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4120 - accuracy: 0.8168 - auc: 0.8960 - val_loss: 0.3999 - val_accuracy: 0.8466 - val_auc: 0.9078
# Epoch 624/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4116 - accuracy: 0.8176 - auc: 0.8965 - val_loss: 0.3999 - val_accuracy: 0.8466 - val_auc: 0.9072
# Epoch 625/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4050 - accuracy: 0.8339 - auc: 0.9016 - val_loss: 0.3980 - val_accuracy: 0.8466 - val_auc: 0.9085
# Epoch 626/700
# 19/19 [==============================] - 1s 27ms/step - loss: 0.3981 - accuracy: 0.8193 - auc: 0.9044 - val_loss: 0.3976 - val_accuracy: 0.8466 - val_auc: 0.9088
# Epoch 627/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4064 - accuracy: 0.8288 - auc: 0.9014 - val_loss: 0.3979 - val_accuracy: 0.8466 - val_auc: 0.9081
# Epoch 628/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4077 - accuracy: 0.8151 - auc: 0.8991 - val_loss: 0.3978 - val_accuracy: 0.8466 - val_auc: 0.9086
# Epoch 629/700
# 19/19 [==============================] - 1s 27ms/step - loss: 0.
700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4055 - accuracy: 0.8322 - auc: 0.8991 - val_loss: 0.3947 - val_accuracy: 0.8466 - val_auc: 0.9109
# Epoch 674/700
# 19/19 [==============================] - 1s 37ms/step - loss: 0.4137 - accuracy: 0.8116 - auc: 0.8947 - val_loss: 0.3927 - val_accuracy: 0.8466 - val_auc: 0.9118
# Epoch 675/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.3995 - accuracy: 0.8236 - auc: 0.9043 - val_loss: 0.3921 - val_accuracy: 0.8493 - val_auc: 0.9114
# Epoch 676/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.4095 - accuracy: 0.8296 - auc: 0.8993 - val_loss: 0.3927 - val_accuracy: 0.8466 - val_auc: 0.9113
# Epoch 677/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4119 - accuracy: 0.8211 - auc: 0.8954 - val_loss: 0.3923 - val_accuracy: 0.8493 - val_auc: 0.9112
# Epoch 678/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4061 - accuracy: 0.8219 - auc: 0.9001 - val_loss: 0.3927 - val_accuracy: 0.8493 - val_auc: 0.9113
# Epoch 679/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4056 - accuracy: 0.8279 - auc: 0.9006 - val_loss: 0.3928 - val_accuracy: 0.8466 - val_auc: 0.9109
# Epoch 680/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4061 - accuracy: 0.8176 - auc: 0.8994 - val_loss: 0.3926 - val_accuracy: 0.8493 - val_auc: 0.9114
# Epoch 681/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4027 - accuracy: 0.8176 - auc: 0.9018 - val_loss: 0.3928 - val_accuracy: 0.8521 - val_auc: 0.9125
# Epoch 682/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4060 - accuracy: 0.8159 - auc: 0.8994 - val_loss: 0.3927 - val_accuracy: 0.8493 - val_auc: 0.9115
# Epoch 683/700
# 19/19 [==============================] - 1s 30ms/step - loss: 0.4049 - accuracy: 0.8296 - auc: 0.9003 - val_loss: 0.3933 - val_accuracy: 0.8438 - val_auc: 0.9110
# Epoch 684/700
# 19/19 [==============================] - 1s 28ms/step - loss: 0.4038 - accuracy: 0.8219 - auc: 0.9010 - val_loss: 0.3932 - val_accuracy: 0.8493 - val_auc: 0.9104
# Epoch 685/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4138 - accuracy: 0.8142 - auc: 0.8944 - val_loss: 0.3939 - val_accuracy: 0.8438 - val_auc: 0.9099
# Epoch 686/700
# 19/19 [==============================] - 1s 31ms/step - loss: 0.4046 - accuracy: 0.8279 - auc: 0.9011 - val_loss: 0.3914 - val_accuracy: 0.8493 - val_auc: 0.9116
# Epoch 687/700
# 19/19 [==============================] - 1s 31ms/step - loss: 0.4030 - accuracy: 0.8193 - auc: 0.9015 - val_loss: 0.3911 - val_accuracy: 0.8493 - val_auc: 0.9117
# Epoch 688/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.3964 - accuracy: 0.8399 - auc: 0.9065 - val_loss: 0.3926 - val_accuracy: 0.8493 - val_auc: 0.9116
# Epoch 689/700
# 19/19 [==============================] - 1s 27ms/step - loss: 0.4030 - accuracy: 0.8262 - auc: 0.9011 - val_loss: 0.3928 - val_accuracy: 0.8466 - val_auc: 0.9110
# Epoch 690/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.4080 - accuracy: 0.8271 - auc: 0.8998 - val_loss: 0.3930 - val_accuracy: 0.8493 - val_auc: 0.9116
# Epoch 691/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.4034 - accuracy: 0.8271 - auc: 0.9024 - val_loss: 0.3944 - val_accuracy: 0.8493 - val_auc: 0.9106
# Epoch 692/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.3981 - accuracy: 0.8193 - auc: 0.9046 - val_loss: 0.3940 - val_accuracy: 0.8521 - val_auc: 0.9112
# Epoch 693/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.3980 - accuracy: 0.8339 - auc: 0.9061 - val_loss: 0.3922 - val_accuracy: 0.8493 - val_auc: 0.9116
# Epoch 694/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.4041 - accuracy: 0.8219 - auc: 0.9014 - val_loss: 0.3929 - val_accuracy: 0.8466 - val_auc: 0.9108
# Epoch 695/700
# 19/19 [==============================] - 0s 24ms/step - loss: 0.4068 - accuracy: 0.8313 - auc: 0.9003 - val_loss: 0.3919 - val_accuracy: 0.8493 - val_auc: 0.9114
# Epoch 696/700
# 19/19 [==============================] - 0s 26ms/step - loss: 0.4143 - accuracy: 0.8288 - auc: 0.8956 - val_loss: 0.3915 - val_accuracy: 0.8493 - val_auc: 0.9117
# Epoch 697/700
# 19/19 [==============================] - 0s 26ms/step - loss: 0.4121 - accuracy: 0.8202 - auc: 0.8958 - val_loss: 0.3924 - val_accuracy: 0.8466 - val_auc: 0.9110
# Epoch 698/700
# 19/19 [==============================] - 0s 25ms/step - loss: 0.4180 - accuracy: 0.8176 - auc: 0.8921 - val_loss: 0.3925 - val_accuracy: 0.8493 - val_auc: 0.9114
# Epoch 699/700
# 19/19 [==============================] - 0s 26ms/step - loss: 0.4111 - accuracy: 0.8125 - auc: 0.8966 - val_loss: 0.3927 - val_accuracy: 0.8466 - val_auc: 0.9109
# Epoch 700/700
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4075 - accuracy: 0.8262 - auc: 0.8980 - val_loss: 0.3931 - val_accuracy: 0.8466 - val_auc: 0.9106

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('(True Negatives): ', cm[0][0])
  print('(False Positives): ', cm[0][1])
  print('(False Negatives): ', cm[1][0])
  print('(True Positives): ', cm[1][1])
  print('Total emotions_happy: ', np.sum(cm[1]))

# %% [markdown]
# test prediction

# %%
model = load_model('neutral_ravdess.hdf5')
test_predictions_baseline = model.predict(X_test)
baseline_results = model.evaluate(X_test, y_test,
                                  batch_size= 64, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()

y_pred = np.argmax(test_predictions_baseline, axis= 1)
yy_test = np.argmax(y_test, axis  = 1)
plot_cm(yy_test, y_pred)

print(classification_report(yy_test, y_pred))
# Out:
# loss :  0.3910542130470276
# accuracy :  0.8493150472640991
# auc :  0.9116982221603394
#
# (True Negatives):  166
# (False Positives):  51
# (False Negatives):  4
# (True Positives):  144
# Total emotions_happy:  148
#               precision    recall  f1-score   support
#
#            0       0.98      0.76      0.86       217
#            1       0.74      0.97      0.84       148
#
#     accuracy                           0.85       365
#    macro avg       0.86      0.87      0.85       365
# weighted avg       0.88      0.85      0.85       365

# %% [markdown]
# Validation

# %%
val_predictions_baseline = model.predict(X_val)
baseline_results = model.evaluate(X_val, y_val,
                                  batch_size= 64, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()

y_pred_val = np.argmax(val_predictions_baseline, axis= 1)
yy_val = np.argmax(y_val, axis  = 1)
plot_cm(yy_val, y_pred_val)

print(classification_report(yy_val, y_pred_val))
# Out:
# loss :  0.389478862285614
# accuracy :  0.8321917653083801
# auc :  0.912161111831665
#
# (True Negatives):  140
# (False Positives):  42
# (False Negatives):  7
# (True Positives):  103
# Total emotions_happy:  110
#               precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85       182
#            1       0.71      0.94      0.81       110
#
#     accuracy                           0.83       292
#    macro avg       0.83      0.85      0.83       292
# weighted avg       0.86      0.83      0.83       292
