# %%
from __future__ import print_function

#Numpy, pandas ans os
import numpy as np
import pandas as pd
import os
# matplotlib for displaying the output
import matplotlib.pyplot as plt

# Librosa for audio
import librosa


#parselmouth for audio
import parselmouth
from parselmouth.praat import call
from sklearn.decomposition import PCA
import statistics

#essentia

import essentia.standard
import essentia.streaming
from essentia.standard import *


#librairies for classification
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split, cross_val_predict, KFold, cross_val_score
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import classification_report, make_scorer, confusion_matrix

from sklearn.metrics import roc_auc_score
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline

from imblearn.over_sampling import ADASYN
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest

from sklearn.model_selection import GridSearchCV
import joblib

#Deep learning

### Plot imports ###

import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras.models import load_model
import seaborn as sns 
from keras.utils import np_utils
from keras.utils import plot_model
from sklearn.preprocessing import LabelEncoder

#for warning
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category= ConvergenceWarning)

warnings.filterwarnings("ignore", category= UserWarning)
warnings.filterwarnings("ignore", category= RuntimeWarning)

# %% [markdown]
# Dataframe to match audio with emotion

# %%
parent_dir = "ravdess_meld" #audio data folder
def prepare_datadf(parent_dir): # a function whose parameter is the audio folder
    df = pd.DataFrame(columns = ['audio', 'label']) #dataframe columns
    
    for  fichier_audio in os.listdir(parent_dir): # for each element in the audio folder
        folder_path = os.path.join(parent_dir, fichier_audio) # path of each item  in the audio folder
        
       
        
        if(os.path.isdir(folder_path)): 
            audios = os.listdir(folder_path) #content of each emotional file
            for i in audios:
                emotion = None
                if i.endswith('outNoise.wav'):
                    if i.startswith("happy"):  ##this specifies that we class happy emotion against the others
                                    #the files corresponding to each emotion started by the name of the emotion
                                    # for example for the emotion "sad" , it will be (if i.startswith("sad"))
                        emotion = 1
                    
                    else:
                        emotion = 0
                    df = df.append(pd.DataFrame({'audio':[os.path.join(fichier_audio, i)], 'label':[emotion]}), 
                           ignore_index=True) # adding values to the defined df:
                                            #the audio column will take the audios_path, 
                                            #and the emotion column will take the corresponding emotion, ie the name of the folder
    #Shuffling for randomness
    df = df.sample(frac=1.0).reset_index(drop=True)
    return df
datadf = prepare_datadf(parent_dir) #function call
display(datadf.head()) #dataframe display
# Out:
#                                                audio label
# 0  fearfull/fearfull_03-01-06-02-01-01-21_norm_ou...     0
# 1  surprised/suprised_03-01-08-01-02-01-08_norm_o...     0
# 2  disgust/disgust_03-01-07-01-01-01-13_norm_outN...     0
# 3  angry/angry_03-01-05-02-02-02-01_norm_outNoise...     0
# 4   surprised/suprised_dia74_utt10_norm_outNoise.wav     0

# %% [markdown]
# Number of labels 1 and 0

# %%
array=datadf.values
audios=array[:,0]
emotions=array[:,1]
print(datadf.label.value_counts())
# Out:
# 0    1939
# 1     349
# Name: label, dtype: int64

# %% [markdown]
# Preprocessing

# %% [markdown]
# Function for framing and windowing the audio_files

# %%
def fram_window(audio_path):
    loader = essentia.standard.MonoLoader(filename= audio_path)

    # and then we actually perform the loading:
    audio = loader()

    w = Windowing(type = 'hann')
    spectrum = Spectrum() 
    #default parameter (hopsize and framesize)
    hopSize = 512
    frameSize = 1024 
    for frame in FrameGenerator(audio, frameSize=1024, hopSize=512, startFromZero=True):
        spect = spectrum(w(frame))
    return spect

# %% [markdown]
# function for features extraction:

# %%
def extract_features(audio_path):
    features = []
    
    
    #Load audios with the different libraries
      
    y,sr = librosa.load(audio_path)
    sound = parselmouth.Sound(audio_path)
    fs, sig = scipy.io.wavfile.read(audio_path) 
    
    pitch = call(sound, "To Pitch", 0.0, 75, 600)
    mean_pitch = call(pitch, "Get mean", 0, 0, "Hertz")
    
    spec =  fram_window(audio_path) 
    duration = librosa.get_duration(y= spec, sr=sr)
    energy = np.sum(spec ** 2) / np.float64(len(spec))
            
    lpc = librosa.core.lpc(spec,16)
            
    zcr = librosa.feature.zero_crossing_rate(spec)
               
    #gfccs = gfcc(sig= spec, fs=fs, num_ceps=13)    
    mfcc = librosa.feature.mfcc(y= spec, sr=sr, n_mfcc = 13)
        
    harmonicity = call(sound, "To Harmonicity (cc)", 0.01, 75, 0.1, 1.0)
    HNR = call(harmonicity, "Get mean", 0, 0)
                
    pointProcess = call(sound, "To PointProcess (periodic, cc)", 75, 500)
    localJitter = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
    localabsoluteJitter = call(pointProcess, "Get jitter (local, absolute)", 0, 0, 0.0001, 0.02, 1.3)

    localShimmer =  call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    localdbShimmer = call([sound, pointProcess], "Get shimmer (local_dB)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
        
    formants = call(sound, "To Formant (burg)", 0.0, 5, 5500, 0.025, 100)
    numPoints = call(pointProcess, "Get number of points")

    f1_list = []
    f2_list = []
    f3_list = []
    f4_list = []
    
    # Measure formants only at glottal pulses
    for point in range(0, numPoints):
        point += 1
        t = call(pointProcess, "Get time from index", point)
        f1 = call(formants, "Get value at time", 1, t, 'Hertz', 'Linear')
        f2 = call(formants, "Get value at time", 2, t, 'Hertz', 'Linear')
        f3 = call(formants, "Get value at time", 3, t, 'Hertz', 'Linear')
        f4 = call(formants, "Get value at time", 4, t, 'Hertz', 'Linear')
        f1_list.append(f1)
        f2_list.append(f2)
        f3_list.append(f3)
        f4_list.append(f4)
        
    f1_list = [f1 for f1 in f1_list if str(f1) != 'nan']
    f2_list = [f2 for f2 in f2_list if str(f2) != 'nan']
    f3_list = [f3 for f3 in f3_list if str(f3) != 'nan']
    
    f4_list = [f4 for f4 in f4_list if str(f4) != 'nan']

    f1_mean = statistics.mean(f1_list)
    f2_mean = statistics.mean(f2_list)
    f3_mean = statistics.mean(f3_list)
    f4_mean = statistics.mean(f4_list)
    
    rapJitter = call(pointProcess, "Get jitter (rap)", 0, 0, 0.0001, 0.02, 1.3)
    ppq5Jitter = call(pointProcess, "Get jitter (ppq5)", 0, 0, 0.0001, 0.02, 1.3)
    ddpJitter = call(pointProcess, "Get jitter (ddp)", 0, 0, 0.0001, 0.02, 1.3)   
            
    apq3Shimmer = call([sound, pointProcess], "Get shimmer (apq3)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    aqpq5Shimmer = call([sound, pointProcess], "Get shimmer (apq5)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq11Shimmer =  call([sound, pointProcess], "Get shimmer (apq11)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    ddaShimmer = call([sound, pointProcess], "Get shimmer (dda)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    
    features.append(mean_pitch)
    features.append(duration)
    features.append(energy)
    features.append(np.mean(zcr))
    features.append(np.mean(lpc))
    
        
    features.append(np.mean(mfcc))
    
    #features.append(np.mean(gfccs))
    features.append(HNR)
    
    features.append(localJitter)
    features.append(np.mean(localabsoluteJitter))
    
    features.append(localShimmer)
    features.append(localdbShimmer)
    features.append(f1_mean)   
    features.append(f2_mean)
    features.append(f3_mean)
    features.append(f4_mean)
        
    features.append(rapJitter)
    features.append(ppq5Jitter)
    features.append(ddpJitter)
    
    features.append(apq3Shimmer)
    features.append(aqpq5Shimmer)
    features.append(apq11Shimmer)
    features.append(ddaShimmer)
        
    return features

# %% [markdown]
# Application of features extraction function on all audios

# %%
all_features = []
for audio_file in array[:,0]:
    if audio_file.endswith('.wav'):
        
        features = extract_features(parent_dir+'/'+audio_file)
        all_features.append(features)

# %%
print(len(all_features))
# Out:
# 2288

# %% [markdown]
# Encode labels

# %%
encod = preprocessing.LabelEncoder()
emotions = array[:,1]
encod.fit(emotions)
list(encod.classes_)
labels=encod.transform(emotions)

# %% [markdown]
# Scale features

# %%
scaler = StandardScaler()
scaler.fit(all_features)
X_scaler = scaler.transform(all_features)

# %% [markdown]
# Oversampling

# %%
ada = ADASYN(sampling_strategy = 0.6)
X, y = ada.fit_sample(X_scaler, labels.ravel())
print("After OverSampling, counts of label '1': {}".format(sum(y==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y==0)))
# Out:
# After OverSampling, counts of label '1': 1122
# After OverSampling, counts of label '0': 1939

# %% [markdown]
# Process to select features after oversampling with ADASYN : the code first takes in a list the position of the features that are deleted, during the 1000 iterations, then uses a dataframe to count them. we notice that the features "[1, 3, 4, 5, 9, 10, 14, 18, 19, 21]   " are deleted 592 times.

# %%
compt=0
df = pd.DataFrame(columns = ['iteration', 'X_removed'])
while compt < 1000:
    ada = ADASYN(sampling_strategy = 0.6)
    
    X, y = ada.fit_sample(X_scaler, labels.ravel())
    X = np.asarray(X)
    Kbest = SelectKBest(k="all")
    selec_features = Kbest.fit(X, y)
    alpha = 0.01
    #remove non_signifiant features selection
    X_selec = X[:,np.where(selec_features.pvalues_ < alpha)[0]]
    
    pos_removed = []    
    for i in range(len(X[0])):
   
        if X[0][i] not in X_selec[0]:
            #print(i)
            pos_removed.append(i)
            str_pos_removed = str(pos_removed)
    #print(pos_removed)
    
    compt = compt + 1
    df= df.append(pd.DataFrame({'iteration':[compt], 'X_removed':[str_pos_removed]}), ignore_index=True)
display(df.head())

print("Number of occurrences of features that are removed :")
df["X_removed"].value_counts()
# Out:
#   iteration                                X_removed
# 0         1  [1, 3, 4, 5, 9, 10, 12, 14, 18, 19, 21]
# 1         2  [1, 3, 4, 5, 9, 10, 12, 14, 18, 19, 21]
# 2         3  [1, 3, 4, 5, 9, 10, 12, 14, 18, 19, 21]
# 3         4      [1, 3, 4, 5, 9, 10, 14, 18, 19, 21]
# 4         5      [1, 3, 4, 5, 9, 10, 14, 18, 19, 21]
# Number of occurrences of features that are removed :
# [1, 3, 4, 5, 9, 10, 14, 18, 19, 21]        592
# [1, 3, 4, 5, 9, 10, 12, 14, 18, 19, 21]    407
# [1, 3, 4, 5, 9, 10, 14, 16, 18, 19, 21]      1
# Name: X_removed, dtype: int64

# %%
#manually feature selection
X_selected = []
for i in range(len(X)):
    #print(w[i][0])
    X_selected.append([X[i][0], X[i][2], X[i][6], X[i][7],  X[i][8],
               X[i][11], X[i][12], X[i][13], X[i][15], X[i][16], X[i][17],
                 X[i][20]])

# %% [markdown]
# Split dataset to Train, Test and Val

# %%
#split train test
X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=1)

print(len(X_train))
print(len(X_test))
print(len(X_val))
# Out:
# 1958
# 613
# 490

# %% [markdown]
# Reshape Labels and features for deep learning model

# %% [markdown]
# Features

# %%
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
X_val = np.asarray(X_val)

# %%
 X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
 X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], 1))

 print(X_train.shape)
 print(X_test.shape)
 print(X_val.shape)
# Out:
# (1958, 12, 1)
# (613, 12, 1)
# (490, 12, 1)

# %% [markdown]
# labels

# %%
from keras.utils import to_categorical

# Encode the classification labels
le = LabelEncoder()
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_val = to_categorical(y_val)

print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (1958, 2)
# (613, 2)
# (490, 2)

# %% [markdown]
# ### Classification

# %% [markdown]
# Model

# %%
input_y = Input(shape= (12,1))

# %%
#CNN
y = Conv1D(256, kernel_size=5, strides= 1,  name='Conv_1', padding = 'same')(input_y)
y = BatchNormalization( name='BatchNorm_1')(y)
y = Activation('elu', name='Activ_1')(y)

y = Conv1D(128, kernel_size=5, strides= 1,  name='Conv_2', padding = 'same')(input_y)
y = Activation('elu', name='Activ_2')(y)

y = Dropout(0.2, name='Drop_1')(y)
y = BatchNormalization( name='BatchNorm_2')(y)
y = MaxPooling1D(pool_size=8, name = 'maxpooling', padding = 'same') (y) 

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_3', padding = 'same')(y)
y = Activation('elu', name='Activ_3')(y)

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_4', padding = 'same')(y)
y = Activation('elu', name='Activ_4')(y)

y = Conv1D(128, kernel_size=5, strides= 1,  name='Conv_5', padding = 'same')(input_y)
y = BatchNormalization( name='BatchNorm_3')(y)
y = Activation('elu', name='Activ_5')(y)

y = Dropout(0.2, name='Drop_2')(y)     

y = Conv1D(128, kernel_size= 5, strides= 1,  name='Conv_6', padding = 'same')(y)

y = Flatten(name='Flat')(y)
y = Dropout(0.2, name='Drop_3')(y)  

y = Dense(y_train.shape[1],  name='dense')(y)

y = BatchNormalization(name='BatchNorm_4')(y)

y = Activation('softmax', name='Activ_6')(y)









# Build final model
model = Model(inputs=input_y, outputs=y)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 12, 1)]           0
# _________________________________________________________________
# Conv_5 (Conv1D)              (None, 12, 128)           768
# _________________________________________________________________
# BatchNorm_3 (BatchNormalizat (None, 12, 128)           512
# _________________________________________________________________
# Activ_5 (Activation)         (None, 12, 128)           0
# _________________________________________________________________
# Drop_2 (Dropout)             (None, 12, 128)           0
# _________________________________________________________________
# Conv_6 (Conv1D)              (None, 12, 128)           82048
# _________________________________________________________________
# Flat (Flatten)               (None, 1536)              0
# _________________________________________________________________
# Drop_3 (Dropout)             (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 3074
# _________________________________________________________________
# BatchNorm_4 (BatchNormalizat (None, 2)                 8
# _________________________________________________________________
# Activ_6 (Activation)         (None, 2)                 0
# =================================================================
# Total params: 86,410
# Trainable params: 86,150
# Non-trainable params: 260
# _________________________________________________________________

# %%
METRICS = [
      
      keras.metrics.BinaryAccuracy(name='accuracy'),
      
      keras.metrics.AUC(name='auc'),
]

# %%
# Compile model
model.compile(optimizer=RMSprop(lr=0.00001, decay=1e-6), loss='categorical_crossentropy', metrics=[METRICS])

# Save best model
best_model_save = ModelCheckpoint('happy_ravdess_meld.hdf5', save_best_only=True, monitor='val_loss', mode='auto')

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience = 30,  verbose=1, mode='auto')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=700, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/700
# 31/31 [==============================] - 1s 34ms/step - loss: 0.7437 - accuracy: 0.5271 - auc: 0.5341 - val_loss: 0.6777 - val_accuracy: 0.6020 - val_auc: 0.6438
# Epoch 2/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.7228 - accuracy: 0.5490 - auc: 0.5532 - val_loss: 0.6742 - val_accuracy: 0.6085 - val_auc: 0.6662
# Epoch 3/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.7051 - accuracy: 0.5506 - auc: 0.5658 - val_loss: 0.6741 - val_accuracy: 0.6134 - val_auc: 0.6647
# Epoch 4/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.7085 - accuracy: 0.5419 - auc: 0.5520 - val_loss: 0.6760 - val_accuracy: 0.6011 - val_auc: 0.6549
# Epoch 5/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6896 - accuracy: 0.5598 - auc: 0.5837 - val_loss: 0.6777 - val_accuracy: 0.6069 - val_auc: 0.6419
# Epoch 6/700
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6930 - accuracy: 0.5414 - auc: 0.5681 - val_loss: 0.6797 - val_accuracy: 0.6003 - val_auc: 0.6200
# Epoch 7/700
# 31/31 [==============================] - 1s 34ms/step - loss: 0.6924 - accuracy: 0.5557 - auc: 0.5757 - val_loss: 0.6810 - val_accuracy: 0.5889 - val_auc: 0.6051
# Epoch 8/700
# 31/31 [==============================] - 1s 34ms/step - loss: 0.6875 - accuracy: 0.5577 - auc: 0.5752 - val_loss: 0.6815 - val_accuracy: 0.5726 - val_auc: 0.5952
# Epoch 9/700
# 31/31 [==============================] - 1s 35ms/step - loss: 0.6842 - accuracy: 0.5598 - auc: 0.5889 - val_loss: 0.6821 - val_accuracy: 0.5595 - val_auc: 0.5855
# Epoch 10/700
# 31/31 [==============================] - 1s 34ms/step - loss: 0.6856 - accuracy: 0.5598 - auc: 0.5846 - val_loss: 0.6822 - val_accuracy: 0.5530 - val_auc: 0.5806
# Epoch 11/700
# 31/31 [==============================] - 1s 37ms/step - loss: 0.6795 - accuracy: 0.5628 - auc: 0.5967 - val_loss: 0.6809 - val_accuracy: 0.5579 - val_auc: 0.5851
# Epoch 12/700
# 31/31 [==============================] - 1s 36ms/step - loss: 0.6795 - accuracy: 0.5787 - auc: 0.5992 - val_loss: 0.6803 - val_accuracy: 0.5546 - val_auc: 0.5855
# Epoch 13/700
# 31/31 [==============================] - 1s 24ms/step - loss: 0.6763 - accuracy: 0.5705 - auc: 0.6012 - val_loss: 0.6774 - val_accuracy: 0.5546 - val_auc: 0.5934
# Epoch 14/700
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6704 - accuracy: 0.5899 - auc: 0.6190 - val_loss: 0.6750 - val_accuracy: 0.5579 - val_auc: 0.6023
# Epoch 15/700
# 31/31 [==============================] - 1s 45ms/step - loss: 0.6733 - accuracy: 0.5756 - auc: 0.6058 - val_loss: 0.6719 - val_accuracy: 0.5612 - val_auc: 0.6088
# Epoch 16/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6806 - accuracy: 0.5863 - auc: 0.6001 - val_loss: 0.6691 - val_accuracy: 0.5710 - val_auc: 0.6160
# Epoch 17/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6730 - accuracy: 0.5751 - auc: 0.6086 - val_loss: 0.6668 - val_accuracy: 0.5775 - val_auc: 0.6217
# Epoch 18/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6762 - accuracy: 0.5644 - auc: 0.6025 - val_loss: 0.6651 - val_accuracy: 0.5759 - val_auc: 0.6254
# Epoch 19/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6684 - accuracy: 0.5797 - auc: 0.6165 - val_loss: 0.6625 - val_accuracy: 0.5856 - val_auc: 0.6308
# Epoch 20/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6715 - accuracy: 0.5787 - auc: 0.6154 - val_loss: 0.6618 - val_accuracy: 0.5938 - val_auc: 0.6325
# Epoch 21/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6684 - accuracy: 0.5940 - auc: 0.6231 - val_loss: 0.6603 - val_accuracy: 0.6020 - val_auc: 0.6352
# Epoch 22/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6690 - accuracy: 0.5904 - auc: 0.6218 - val_loss: 0.6585 - val_accuracy: 0.6020 - val_auc: 0.6399
# Epoch 23/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6651 - accuracy: 0.5848 - auc: 0.6273 - val_loss: 0.6581 - val_accuracy: 0.6036 - val_auc: 0.6391
# Epoch 24/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6669 - accuracy: 0.5873 - auc: 0.6227 - val_loss: 0.6578 - val_accuracy: 0.6052 - val_auc: 0.6406
# Epoch 25/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6669 - accuracy: 0.5843 - auc: 0.6213 - val_loss: 0.6575 - val_accuracy: 0.6052 - val_auc: 0.6410
# Epoch 26/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6657 - accuracy: 0.5868 - auc: 0.6255 - val_loss: 0.6581 - val_accuracy: 0.6036 - val_auc: 0.6386
# Epoch 27/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6664 - accuracy: 0.5812 - auc: 0.6240 - val_loss: 0.6580 - val_accuracy: 0.6020 - val_auc: 0.6385
# Epoch 28/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6581 - accuracy: 0.5950 - auc: 0.6457 - val_loss: 0.6583 - val_accuracy: 0.6003 - val_auc: 0.6372
# Epoch 29/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6670 - accuracy: 0.5878 - auc: 0.6258 - val_loss: 0.6578 - val_accuracy: 0.5971 - val_auc: 0.6374
# Epoch 30/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6637 - accuracy: 0.5924 - auc: 0.6315 - val_loss: 0.6571 - val_accuracy: 0.5987 - val_auc: 0.6398
# Epoch 31/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6608 - accuracy: 0.5843 - auc: 0.6357 - val_loss: 0.6569 - val_accuracy: 0.5987 - val_auc: 0.6398
# Epoch 32/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6539 - accuracy: 0.6001 - auc: 0.6486 - val_loss: 0.6566 - val_accuracy: 0.6020 - val_auc: 0.6405
# Epoch 33/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6555 - accuracy: 0.6016 - auc: 0.6491 - val_loss: 0.6562 - val_accuracy: 0.5987 - val_auc: 0.6407
# Epoch 34/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6627 - accuracy: 0.5930 - auc: 0.6357 - val_loss: 0.6567 - val_accuracy: 0.5987 - val_auc: 0.6395
# Epoch 35/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6623 - accuracy: 0.5868 - auc: 0.6311 - val_loss: 0.6567 - val_accuracy: 0.5971 - val_auc: 0.6398
# Epoch 36/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6646 - accuracy: 0.5909 - auc: 0.6313 - val_loss: 0.6572 - val_accuracy: 0.5954 - val_auc: 0.6387
# Epoch 37/700
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6645 - accuracy: 0.5914 - auc: 0.6285 - val_loss: 0.6568 - val_accuracy: 0.5889 - val_auc: 0.6387
# Epoch 38/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6649 - accuracy: 0.5843 - auc: 0.6258 - val_loss: 0.6558 - val_accuracy: 0.5971 - val_auc: 0.6415
# Epoch 39/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6591 - accuracy: 0.5924 - auc: 0.6369 - val_loss: 0.6561 - val_accuracy: 0.5987 - val_auc: 0.6407
# Epoch 40/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6567 - accuracy: 0.6067 - auc: 0.6502 - val_loss: 0.6558 - val_accuracy: 0.6052 - val_auc: 0.6425
# Epoch 41/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6625 - accuracy: 0.6006 - auc: 0.6383 - val_loss: 0.6557 - val_accuracy: 0.6020 - val_auc: 0.6431
# Epoch 42/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6525 - accuracy: 0.6088 - auc: 0.6546 - val_loss: 0.6561 - val_accuracy: 0.6052 - val_auc: 0.6416
# Epoch 43/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6584 - accuracy: 0.5868 - auc: 0.6406 - val_loss: 0.6555 - val_accuracy: 0.6069 - val_auc: 0.6435
# Epoch 44/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6603 - accuracy: 0.5904 - auc: 0.6391 - val_loss: 0.6552 - val_accuracy: 0.6003 - val_auc: 0.6435
# Epoch 45/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6576 - accuracy: 0.5965 - auc: 0.6453 - val_loss: 0.6556 - val_accuracy: 0.6069 - val_auc: 0.6423
# Epoch 46/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6631 - accuracy: 0.5843 - auc: 0.6345 - val_loss: 0.6555 - val_accuracy: 0.5987 - val_auc: 0.6429
# Epoch 47/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6582 - accuracy: 0.5899 - auc: 0.6401 - val_loss: 0.6561 - val_accuracy: 0.5971 - val_auc: 0.6411
# Epoch 48/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6565 - accuracy: 0.5945 - auc: 0.6426 - val_loss: 0.6557 - val_accuracy: 0.5971 - val_auc: 0.6421
# Epoch 49/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6563 - accuracy: 0.5970 - auc: 0.6483 - val_loss: 0.6557 - val_accuracy: 0.5971 - val_auc: 0.6415
# Epoch 50/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6614 - accuracy: 0.6001 - auc: 0.6383 - val_loss: 0.6556 - val_accuracy: 0.5987 - val_auc: 0.6420
# Epoch 51/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6541 - accuracy: 0.5965 - auc: 0.6489 - val_loss: 0.6554 - val_accuracy: 0.6052 - val_auc: 0.6418
# Epoch 52/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6553 - accuracy: 0.5981 - auc: 0.6472 - val_loss: 0.6562 - val_accuracy: 0.5987 - val_auc: 0.6404
# Epoch 53/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6563 - accuracy: 0.5960 - auc: 0.6447 - val_loss: 0.6557 - val_accuracy: 0.6020 - val_auc: 0.6418
# Epoch 54/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.
700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6424 - accuracy: 0.6226 - auc: 0.6743 - val_loss: 0.6533 - val_accuracy: 0.6036 - val_auc: 0.6476
# Epoch 99/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6411 - accuracy: 0.6144 - auc: 0.6744 - val_loss: 0.6537 - val_accuracy: 0.6052 - val_auc: 0.6468
# Epoch 100/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6433 - accuracy: 0.6231 - auc: 0.6741 - val_loss: 0.6535 - val_accuracy: 0.5971 - val_auc: 0.6471
# Epoch 101/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6428 - accuracy: 0.6200 - auc: 0.6738 - val_loss: 0.6538 - val_accuracy: 0.5987 - val_auc: 0.6453
# Epoch 102/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6428 - accuracy: 0.6190 - auc: 0.6691 - val_loss: 0.6535 - val_accuracy: 0.6003 - val_auc: 0.6460
# Epoch 103/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6418 - accuracy: 0.6292 - auc: 0.6768 - val_loss: 0.6535 - val_accuracy: 0.5987 - val_auc: 0.6461
# Epoch 104/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6422 - accuracy: 0.6297 - auc: 0.6807 - val_loss: 0.6536 - val_accuracy: 0.5971 - val_auc: 0.6460
# Epoch 105/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6426 - accuracy: 0.6323 - auc: 0.6745 - val_loss: 0.6530 - val_accuracy: 0.5971 - val_auc: 0.6470
# Epoch 106/700
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6432 - accuracy: 0.6267 - auc: 0.6745 - val_loss: 0.6528 - val_accuracy: 0.5954 - val_auc: 0.6476
# Epoch 107/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6394 - accuracy: 0.6144 - auc: 0.6756 - val_loss: 0.6528 - val_accuracy: 0.5987 - val_auc: 0.6475
# Epoch 108/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6402 - accuracy: 0.6313 - auc: 0.6805 - val_loss: 0.6521 - val_accuracy: 0.5987 - val_auc: 0.6494
# Epoch 109/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6404 - accuracy: 0.6170 - auc: 0.6753 - val_loss: 0.6524 - val_accuracy: 0.6036 - val_auc: 0.6502
# Epoch 110/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6430 - accuracy: 0.6154 - auc: 0.6722 - val_loss: 0.6519 - val_accuracy: 0.6003 - val_auc: 0.6511
# Epoch 111/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6402 - accuracy: 0.6185 - auc: 0.6769 - val_loss: 0.6512 - val_accuracy: 0.5971 - val_auc: 0.6517
# Epoch 112/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6394 - accuracy: 0.6241 - auc: 0.6811 - val_loss: 0.6519 - val_accuracy: 0.5987 - val_auc: 0.6505
# Epoch 113/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6362 - accuracy: 0.6313 - auc: 0.6849 - val_loss: 0.6517 - val_accuracy: 0.5971 - val_auc: 0.6500
# Epoch 114/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6384 - accuracy: 0.6318 - auc: 0.6860 - val_loss: 0.6522 - val_accuracy: 0.5954 - val_auc: 0.6491
# Epoch 115/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6399 - accuracy: 0.6256 - auc: 0.6773 - val_loss: 0.6522 - val_accuracy: 0.5971 - val_auc: 0.6488
# Epoch 116/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6398 - accuracy: 0.6328 - auc: 0.6783 - val_loss: 0.6525 - val_accuracy: 0.6003 - val_auc: 0.6482
# Epoch 117/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6470 - accuracy: 0.6159 - auc: 0.6674 - val_loss: 0.6526 - val_accuracy: 0.6003 - val_auc: 0.6484
# Epoch 118/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6399 - accuracy: 0.6261 - auc: 0.6767 - val_loss: 0.6519 - val_accuracy: 0.5987 - val_auc: 0.6494
# Epoch 119/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.
700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6356 - accuracy: 0.6256 - auc: 0.6863 - val_loss: 0.6486 - val_accuracy: 0.6020 - val_auc: 0.6564
# Epoch 164/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6300 - accuracy: 0.6313 - auc: 0.6955 - val_loss: 0.6487 - val_accuracy: 0.5987 - val_auc: 0.6565
# Epoch 165/700
# 31/31 [==============================] - 1s 23ms/step - loss: 0.6330 - accuracy: 0.6399 - auc: 0.6910 - val_loss: 0.6484 - val_accuracy: 0.5987 - val_auc: 0.6572
# Epoch 166/700
# 31/31 [==============================] - 1s 23ms/step - loss: 0.6343 - accuracy: 0.6318 - auc: 0.6887 - val_loss: 0.6488 - val_accuracy: 0.6003 - val_auc: 0.6565
# Epoch 167/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6354 - accuracy: 0.6343 - auc: 0.6876 - val_loss: 0.6481 - val_accuracy: 0.5971 - val_auc: 0.6574
# Epoch 168/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6285 - accuracy: 0.6374 - auc: 0.6978 - val_loss: 0.6480 - val_accuracy: 0.5987 - val_auc: 0.6585
# Epoch 169/700
# 31/31 [==============================] - 1s 24ms/step - loss: 0.6294 - accuracy: 0.6359 - auc: 0.6985 - val_loss: 0.6478 - val_accuracy: 0.5971 - val_auc: 0.6582
# Epoch 170/700
# 31/31 [==============================] - 1s 24ms/step - loss: 0.6323 - accuracy: 0.6318 - auc: 0.6892 - val_loss: 0.6473 - val_accuracy: 0.5971 - val_auc: 0.6593
# Epoch 171/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6302 - accuracy: 0.6287 - auc: 0.6926 - val_loss: 0.6468 - val_accuracy: 0.6020 - val_auc: 0.6598
# Epoch 172/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6308 - accuracy: 0.6410 - auc: 0.6949 - val_loss: 0.6474 - val_accuracy: 0.5987 - val_auc: 0.6594
# Epoch 173/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6353 - accuracy: 0.6282 - auc: 0.6877 - val_loss: 0.6473 - val_accuracy: 0.6020 - val_auc: 0.6590
# Epoch 174/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6339 - accuracy: 0.6338 - auc: 0.6891 - val_loss: 0.6479 - val_accuracy: 0.6020 - val_auc: 0.6577
# Epoch 175/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6346 - accuracy: 0.6277 - auc: 0.6876 - val_loss: 0.6471 - val_accuracy: 0.6036 - val_auc: 0.6595
# Epoch 176/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6330 - accuracy: 0.6323 - auc: 0.6876 - val_loss: 0.6465 - val_accuracy: 0.6020 - val_auc: 0.6606
# Epoch 177/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6279 - accuracy: 0.6466 - auc: 0.6999 - val_loss: 0.6470 - val_accuracy: 0.6003 - val_auc: 0.6598
# Epoch 178/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6362 - accuracy: 0.6359 - auc: 0.6839 - val_loss: 0.6461 - val_accuracy: 0.6052 - val_auc: 0.6604
# Epoch 179/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6248 - accuracy: 0.6440 - auc: 0.7080 - val_loss: 0.6465 - val_accuracy: 0.5987 - val_auc: 0.6600
# Epoch 180/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6339 - accuracy: 0.6318 - auc: 0.6891 - val_loss: 0.6462 - val_accuracy: 0.5987 - val_auc: 0.6601
# Epoch 181/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6391 - accuracy: 0.6307 - auc: 0.6796 - val_loss: 0.6461 - val_accuracy: 0.6003 - val_auc: 0.6612
# Epoch 182/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6289 - accuracy: 0.6297 - auc: 0.6956 - val_loss: 0.6464 - val_accuracy: 0.6020 - val_auc: 0.6605
# Epoch 183/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6338 - accuracy: 0.6374 - auc: 0.6907 - val_loss: 0.6465 - val_accuracy: 0.6003 - val_auc: 0.6604
# Epoch 184/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.
700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.5957 - accuracy: 0.6818 - auc: 0.7470 - val_loss: 0.6194 - val_accuracy: 0.6607 - val_auc: 0.7115
# Epoch 650/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5971 - accuracy: 0.6788 - auc: 0.7448 - val_loss: 0.6198 - val_accuracy: 0.6623 - val_auc: 0.7109
# Epoch 651/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5928 - accuracy: 0.6808 - auc: 0.7521 - val_loss: 0.6202 - val_accuracy: 0.6623 - val_auc: 0.7102
# Epoch 652/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5930 - accuracy: 0.6721 - auc: 0.7504 - val_loss: 0.6203 - val_accuracy: 0.6607 - val_auc: 0.7101
# Epoch 653/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6005 - accuracy: 0.6706 - auc: 0.7412 - val_loss: 0.6202 - val_accuracy: 0.6639 - val_auc: 0.7108
# Epoch 654/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6034 - accuracy: 0.6675 - auc: 0.7349 - val_loss: 0.6204 - val_accuracy: 0.6623 - val_auc: 0.7094
# Epoch 655/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5932 - accuracy: 0.6721 - auc: 0.7507 - val_loss: 0.6209 - val_accuracy: 0.6639 - val_auc: 0.7088
# Epoch 656/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5929 - accuracy: 0.6941 - auc: 0.7540 - val_loss: 0.6208 - val_accuracy: 0.6639 - val_auc: 0.7093
# Epoch 657/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5950 - accuracy: 0.6869 - auc: 0.7494 - val_loss: 0.6206 - val_accuracy: 0.6623 - val_auc: 0.7096
# Epoch 658/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5922 - accuracy: 0.6844 - auc: 0.7490 - val_loss: 0.6200 - val_accuracy: 0.6656 - val_auc: 0.7107
# Epoch 659/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6002 - accuracy: 0.6736 - auc: 0.7426 - val_loss: 0.6201 - val_accuracy: 0.6623 - val_auc: 0.7110
# Epoch 660/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6033 - accuracy: 0.6665 - auc: 0.7347 - val_loss: 0.6196 - val_accuracy: 0.6623 - val_auc: 0.7118
# Epoch 661/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.5981 - accuracy: 0.6772 - auc: 0.7455 - val_loss: 0.6198 - val_accuracy: 0.6639 - val_auc: 0.7110
# Epoch 662/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5914 - accuracy: 0.6777 - auc: 0.7524 - val_loss: 0.6200 - val_accuracy: 0.6623 - val_auc: 0.7107
# Epoch 663/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5968 - accuracy: 0.6803 - auc: 0.7499 - val_loss: 0.6203 - val_accuracy: 0.6607 - val_auc: 0.7104
# Epoch 664/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5965 - accuracy: 0.6685 - auc: 0.7436 - val_loss: 0.6203 - val_accuracy: 0.6574 - val_auc: 0.7100
# Epoch 665/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5979 - accuracy: 0.6777 - auc: 0.7443 - val_loss: 0.6203 - val_accuracy: 0.6623 - val_auc: 0.7100
# Epoch 666/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5930 - accuracy: 0.6818 - auc: 0.7514 - val_loss: 0.6196 - val_accuracy: 0.6607 - val_auc: 0.7112
# Epoch 667/700
# 31/31 [==============================] - 2s 52ms/step - loss: 0.5958 - accuracy: 0.6711 - auc: 0.7452 - val_loss: 0.6194 - val_accuracy: 0.6607 - val_auc: 0.7123
# Epoch 668/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5995 - accuracy: 0.6721 - auc: 0.7419 - val_loss: 0.6196 - val_accuracy: 0.6607 - val_auc: 0.7114
# Epoch 669/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5950 - accuracy: 0.6788 - auc: 0.7481 - val_loss: 0.6195 - val_accuracy: 0.6574 - val_auc: 0.7111
# Epoch 670/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6015 - accuracy: 0.6650 - auc: 0.7376 - val_loss: 0.6200 - val_accuracy: 0.6591 - val_auc: 0.7102
# Epoch 671/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5940 - accuracy: 0.6854 - auc: 0.7500 - val_loss: 0.6200 - val_accuracy: 0.6607 - val_auc: 0.7107
# Epoch 672/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5993 - accuracy: 0.6777 - auc: 0.7426 - val_loss: 0.6199 - val_accuracy: 0.6607 - val_auc: 0.7106
# Epoch 673/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5967 - accuracy: 0.6721 - auc: 0.7476 - val_loss: 0.6201 - val_accuracy: 0.6574 - val_auc: 0.7104
# Epoch 674/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5990 - accuracy: 0.6767 - auc: 0.7402 - val_loss: 0.6188 - val_accuracy: 0.6639 - val_auc: 0.7130
# Epoch 675/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6000 - accuracy: 0.6788 - auc: 0.7438 - val_loss: 0.6190 - val_accuracy: 0.6607 - val_auc: 0.7124
# Epoch 676/700
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6020 - accuracy: 0.6742 - auc: 0.7397 - val_loss: 0.6190 - val_accuracy: 0.6591 - val_auc: 0.7128
# Epoch 677/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5931 - accuracy: 0.6864 - auc: 0.7521 - val_loss: 0.6192 - val_accuracy: 0.6591 - val_auc: 0.7118
# Epoch 678/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5944 - accuracy: 0.6839 - auc: 0.7480 - val_loss: 0.6197 - val_accuracy: 0.6607 - val_auc: 0.7109
# Epoch 679/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5913 - accuracy: 0.6864 - auc: 0.7519 - val_loss: 0.6197 - val_accuracy: 0.6623 - val_auc: 0.7108
# Epoch 680/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5985 - accuracy: 0.6818 - auc: 0.7426 - val_loss: 0.6189 - val_accuracy: 0.6656 - val_auc: 0.7121
# Epoch 681/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5898 - accuracy: 0.6839 - auc: 0.7533 - val_loss: 0.6189 - val_accuracy: 0.6639 - val_auc: 0.7124
# Epoch 682/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5942 - accuracy: 0.6772 - auc: 0.7476 - val_loss: 0.6180 - val_accuracy: 0.6607 - val_auc: 0.7141
# Epoch 683/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.5962 - accuracy: 0.6777 - auc: 0.7451 - val_loss: 0.6178 - val_accuracy: 0.6672 - val_auc: 0.7141
# Epoch 684/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5986 - accuracy: 0.6726 - auc: 0.7411 - val_loss: 0.6182 - val_accuracy: 0.6623 - val_auc: 0.7135
# Epoch 685/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.6035 - accuracy: 0.6706 - auc: 0.7362 - val_loss: 0.6177 - val_accuracy: 0.6639 - val_auc: 0.7147
# Epoch 686/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5941 - accuracy: 0.6813 - auc: 0.7495 - val_loss: 0.6182 - val_accuracy: 0.6639 - val_auc: 0.7132
# Epoch 687/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6025 - accuracy: 0.6716 - auc: 0.7375 - val_loss: 0.6178 - val_accuracy: 0.6672 - val_auc: 0.7147
# Epoch 688/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5972 - accuracy: 0.6777 - auc: 0.7442 - val_loss: 0.6178 - val_accuracy: 0.6656 - val_auc: 0.7142
# Epoch 689/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5905 - accuracy: 0.6813 - auc: 0.7532 - val_loss: 0.6177 - val_accuracy: 0.6607 - val_auc: 0.7144
# Epoch 690/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5973 - accuracy: 0.6772 - auc: 0.7429 - val_loss: 0.6176 - val_accuracy: 0.6623 - val_auc: 0.7149
# Epoch 691/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.5975 - accuracy: 0.6823 - auc: 0.7439 - val_loss: 0.6176 - val_accuracy: 0.6607 - val_auc: 0.7142
# Epoch 692/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5954 - accuracy: 0.6798 - auc: 0.7463 - val_loss: 0.6175 - val_accuracy: 0.6591 - val_auc: 0.7145
# Epoch 693/700
# 31/31 [==============================] - 1s 22ms/step - loss: 0.5933 - accuracy: 0.6905 - auc: 0.7507 - val_loss: 0.6168 - val_accuracy: 0.6639 - val_auc: 0.7161
# Epoch 694/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5939 - accuracy: 0.6767 - auc: 0.7482 - val_loss: 0.6172 - val_accuracy: 0.6639 - val_auc: 0.7146
# Epoch 695/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5950 - accuracy: 0.6864 - auc: 0.7505 - val_loss: 0.6172 - val_accuracy: 0.6656 - val_auc: 0.7152
# Epoch 696/700
# 31/31 [==============================] - 1s 21ms/step - loss: 0.5963 - accuracy: 0.6777 - auc: 0.7452 - val_loss: 0.6167 - val_accuracy: 0.6639 - val_auc: 0.7165
# Epoch 697/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5931 - accuracy: 0.6782 - auc: 0.7486 - val_loss: 0.6168 - val_accuracy: 0.6656 - val_auc: 0.7156
# Epoch 698/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6042 - accuracy: 0.6726 - auc: 0.7361 - val_loss: 0.6174 - val_accuracy: 0.6688 - val_auc: 0.7148
# Epoch 699/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5981 - accuracy: 0.6782 - auc: 0.7480 - val_loss: 0.6181 - val_accuracy: 0.6639 - val_auc: 0.7129
# Epoch 700/700
# 31/31 [==============================] - 1s 20ms/step - loss: 0.5967 - accuracy: 0.6803 - auc: 0.7446 - val_loss: 0.6179 - val_accuracy: 0.6672 - val_auc: 0.7134

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('(True Negatives): ', cm[0][0])
  print('(False Positives): ', cm[0][1])
  print('(False Negatives): ', cm[1][0])
  print('(True Positives): ', cm[1][1])
  print('Total emotions_happy: ', np.sum(cm[1]))

# %% [markdown]
# test prediction

# %%
model = load_model('happy_ravdess_meld.hdf5')
test_predictions_baseline = model.predict(X_test)
baseline_results = model.evaluate(X_test, y_test,
                                  batch_size= 64, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()

y_pred = np.argmax(test_predictions_baseline, axis= 1)
yy_test = np.argmax(y_test, axis  = 1)
plot_cm(yy_test, y_pred)

print(classification_report(yy_test, y_pred))
# Out:
# loss :  0.6167088150978088
# accuracy :  0.6639478206634521
# auc :  0.7164907455444336
#
# (True Negatives):  287
# (False Positives):  113
# (False Negatives):  93
# (True Positives):  120
# Total emotions_happy:  213
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       400
#            1       0.52      0.56      0.54       213
#
#     accuracy                           0.66       613
#    macro avg       0.64      0.64      0.64       613
# weighted avg       0.67      0.66      0.67       613

# %% [markdown]
# Validation

# %%
val_predictions_baseline = model.predict(X_val)
baseline_results = model.evaluate(X_val, y_val,
                                  batch_size= 64, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()

y_pred_val = np.argmax(val_predictions_baseline, axis= 1)
yy_val = np.argmax(y_val, axis  = 1)
plot_cm(yy_val, y_pred_val)

print(classification_report(yy_val, y_pred_val))
# Out:
# loss :  0.6018314361572266
# accuracy :  0.6612244844436646
# auc :  0.7383215427398682
#
# (True Negatives):  220
# (False Positives):  87
# (False Negatives):  79
# (True Positives):  104
# Total emotions_happy:  183
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       307
#            1       0.54      0.57      0.56       183
#
#     accuracy                           0.66       490
#    macro avg       0.64      0.64      0.64       490
# weighted avg       0.66      0.66      0.66       490
